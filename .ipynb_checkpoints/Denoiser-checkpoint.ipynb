# %% [markdown]
# # Denoiser
# An AI module to reduce the noise in any audio using LSTM

# %% [markdown]
# ### Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import librosa

# %% [markdown]
# ### Get Dataset

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#         fname              label      aso_id
# 0  274679.wav  Walk_or_footsteps  /m/07pbtc8
# 1  365220.wav  Walk_or_footsteps  /m/07pbtc8
# 2  233458.wav  Walk_or_footsteps  /m/07pbtc8
# 3  370931.wav  Walk_or_footsteps  /m/07pbtc8
# 4  137172.wav  Walk_or_footsteps  /m/07pbtc8

# %%
df.drop(['aso_id'],axis=1,inplace=True)
df
# Out:
#           fname              label
# 0    274679.wav  Walk_or_footsteps
# 1    365220.wav  Walk_or_footsteps
# 2    233458.wav  Walk_or_footsteps
# 3    370931.wav  Walk_or_footsteps
# 4    137172.wav  Walk_or_footsteps
# ..          ...                ...
# 942  235535.wav             Squeak
# 943  326043.wav            Writing
# 944   62469.wav            Tearing
# 945  273450.wav            Tearing
# 946  120341.wav            Tearing
#
# [947 rows x 2 columns]

# %%
import os
path, dirs, files = next(os.walk("/home/mohan/UrbanSound8K/audio/fold1"))
file_count = len(files)
file_count
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-3-f482dc4b39f2> in <module>
#       1 import os
# ----> 2 path, dirs, files = next(os.walk("/home/mohan/UrbanSound8K/audio/fold1"))
#       3 file_count = len(files)
#       4 file_count
#
# StopIteration:

# %%
import os
path, dirs, files = next(os.walk("/home/theorangeguy/Downloads/Denoiser/dataset"))
file_count = len(files)
file_count

# %%
files
# Out:
# ['266459.wav',
#  '5364.wav',
#  '428815.wav',
#  '377842.wav',
#  '375528.wav',
#  '209873.wav',
#  '85550.wav',
#  '105091.wav',
#  '244926.wav',
#  '377389.wav',
#  '201838.wav',
#  '253807.wav',
#  '133456.wav',
#  '129427.wav',
#  '34796.wav',
#  '52289.wav',
#  '36268.wav',
#  '169928.wav',
#  '412558.wav',
#  '325179.wav',
#  '256308.wav',
#  '178263.wav',
#  '369757.wav',
#  '96025.wav',
#  '409614.wav',
#  '434660.wav',
#  '123805.wav',
#  '217796.wav',
#  '387753.wav',
#  '412135.wav',
#  '58099.wav',
#  '64527.wav',
#  '5361.wav',
#  '392396.wav',
#  '136691.wav',
#  '260391.wav',
#  '158971.wav',
#  '173062.wav',
#  '209870.wav',
#  '149193.wav',
#  '334969.wav',
#  '20738.wav',
#  '18615.wav',
#  '346237.wav',
#  '182120.wav',
#  '393581.wav',
#  '85645.wav',
#  '173719.wav',
#  '364244.wav',
#  '5379.wav',
#  '173674.wav',
#  '214189.wav',
#  '128331.wav',
#  '270225.wav',
#  '163450.wav',
#  '68438.wav',
#  '98073.wav',
#  '58110.wav',
#  '201252.wav',
# ...

# %% [markdown]
# Displaying a wind sample

# %%
import librosa
p='/home/theorangeguy/Downloads/Denoiser/dataset/'
aud=files[800]
audio_data = p+aud
x , sr = librosa.load(audio_data)
print(type(x), type(sr))
print(x.shape, sr)
# Out:
# <class 'numpy.ndarray'> <class 'int'>
# (124892,) 22050

# %%
import librosa
#aud=files[800]
audio_data = '/home/mohan/UrbanSound8K/audio/fold1/101415-3-0-2.wav'
x , sr = librosa.load(audio_data)
print(type(x), type(sr))
print(x.shape, sr)
# Out:
# /home/theorangeguy/.local/lib/python3.6/site-packages/librosa/core/audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     128     try:
# --> 129         with sf.SoundFile(path) as sf_desc:
#     130             sr_native = sf_desc.samplerate
#
# ~/.local/lib/python3.6/site-packages/soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     739                                          format, subtype, endian)
# --> 740         self._file = self._open(file, mode_int, closefd)
#     741         if set(mode).issuperset('r+') and self.seekable():
#
# ...

# %%
librosa.load(audio_data, sr=44100)
import IPython.display as ipd
ipd.Audio(audio_data)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz')
plt.colorbar()

# %% [markdown]
# ### Classification Code

# %%
import librosa
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from PIL import Image
import pathlib
import sklearn.model_selection 
import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import keras
from keras import layers
from keras import layers
import keras
from keras.models import Sequential
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-55f7af57825a> in <module>
#       8 import pathlib
#       9 import sklearn.model_selection
# ---> 10 import train_test_split
#      11 from sklearn.preprocessing import LabelEncoder, StandardScaler
#      12 import keras
#
# ModuleNotFoundError: No module named 'train_test_split'

# %% [markdown]
# aud to spectrogram

# %%
cmap = plt.get_cmap('inferno')
plt.figure(figsize=(8,8))
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
    pathlib.Path(f'img_data/{g}').mkdir(parents=True, exist_ok=True)
    for filename in os.listdir(f'./drive/My Drive/genres/{g}'):
        songname = f'./drive/My Drive/genres/{g}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=5)
        plt.specgram(y, NFFT=2048, Fs=2, Fc=0, noverlap=128, cmap=cmap, sides='default', mode='default', scale='dB');
        plt.axis('off');
        plt.savefig(f'img_data/{g}/{filename[:-3].replace(".", "")}.png')
        plt.clf()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-bda104fa604e> in <module>
#       4 for g in genres:
#       5     pathlib.Path(f'img_data/{g}').mkdir(parents=True, exist_ok=True)
# ----> 6     for filename in os.listdir(f'./drive/My Drive/genres/{g}'):
#       7         songname = f'./drive/My Drive/genres/{g}/{filename}'
#       8         y, sr = librosa.load(songname, mono=True, duration=5)
#
# FileNotFoundError: [Errno 2] No such file or directory: './drive/My Drive/genres/blues'

# %%
#create csv header
header = 'filename chroma_stft rmse spectral_centroid spectral_bandwidth rolloff zero_crossing_rate'
for i in range(1, 21):
    header += f' mfcc{i}'
header += ' label'
header = header.split()

# %%
# Extracting features from Spectrogram: We will extract Mel-frequency cepstral coefficients (MFCC), Spectral Centroid, Zero Crossing Rate, Chroma Frequencies, and Spectral Roll-off.
file = open('dataset.csv', 'w', newline='')
with file:
    writer = csv.writer(file)
    writer.writerow(header)
genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
for g in genres:
    for filename in os.listdir(f'./drive/My Drive/genres/{g}'):
        songname = f'./drive/My Drive/genres/{g}/{filename}'
        y, sr = librosa.load(songname, mono=True, duration=30)
        rmse = librosa.feature.rmse(y=y)
        chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr)
        spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr)
        spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr)
        rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
        zcr = librosa.feature.zero_crossing_rate(y)
        mfcc = librosa.feature.mfcc(y=y, sr=sr)
        to_append = f'{filename} {np.mean(chroma_stft)} {np.mean(rmse)} {np.mean(spec_cent)} {np.mean(spec_bw)} {np.mean(rolloff)} {np.mean(zcr)}'    
        for e in mfcc:

            to_append += f' {np.mean(e)}'
        to_append += f' {g}'
        file = open('dataset.csv', 'a', newline='')
        with file:
            writer = csv.writer(file)
            writer.writerow(to_append.split())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-e4781bb85ca2> in <module>
#       2 file = open('dataset.csv', 'w', newline='')
#       3 with file:
# ----> 4     writer = csv.writer(file)
#       5     writer.writerow(header)
#       6 genres = 'blues classical country disco hiphop jazz metal pop reggae rock'.split()
#
# NameError: name 'csv' is not defined

# %%
# labeling n preprocess
data = pd.read_csv('dataset.csv')
data.head()# Dropping unneccesary columns
data = data.drop(['filename'],axis=1)#Encoding the Labels
genre_list = data.iloc[:, -1]
encoder = LabelEncoder()
y = encoder.fit_transform(genre_list)#Scaling the Feature columns
scaler = StandardScaler()
X = scaler.fit_transform(np.array(data.iloc[:, :-1], dtype = float))#Dividing data into training and Testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-51-29f23ef30dd2> in <module>
#       1 # labeling n preprocess
# ----> 2 data = pd.read_csv('dataset.csv')
#       3 data.head()# Dropping unneccesary columns
#       4 data = data.drop(['filename'],axis=1)#Encoding the Labels
#       5 genre_list = data.iloc[:, -1]
#
# ...

# %%
# normal artif-NN (i'll do LSTM)
model = Sequential()
model.add(layers.Dense(256, activation='relu', input_shape=(X_train.shape[1],)))
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10, activation='softmax'))model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
#   File "<ipython-input-54-52d2739310ce>", line 6
#     model.add(layers.Dense(10, activation='softmax'))model.compile(optimizer='adam',
#                                                          ^
# SyntaxError: invalid syntax

# %%
classifier = model.fit(X_train,
                    y_train,
                    epochs=100,
                    batch_size=128)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-58493ebcde4c> in <module>
# ----> 1 classifier = model.fit(X_train,
#       2                     y_train,
#       3                     epochs=100,
#       4                     batch_size=128)
#
# NameError: name 'model' is not defined
